# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sqlalchemy import create_engine

# Display settings
pd.set_option("display.max_columns", None)

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
engine = create_engine("sqlite:///../bluestock_mf.db")

print("Connected Successfully")
# Out:
# Connected Successfully

# %%
print("Funds Shape:", funds.shape)
print("NAV Shape:", nav.shape)
print("Performance Shape:", performance.shape)
print("Transactions Shape:", transactions.shape)
print("Holdings Shape:", holdings.shape)
# Out:
# Funds Shape: (40, 15)
# NAV Shape: (46000, 3)
# Performance Shape: (40, 19)
# Transactions Shape: (32778, 13)
# Holdings Shape: (322, 8)

# %%
print("=" * 60)
print("DIM FUND")
print("=" * 60)
funds.info()

print("\n" + "=" * 60)
print("FACT PERFORMANCE")
print("=" * 60)
performance.info()

print("\n" + "=" * 60)
print("FACT TRANSACTIONS")
print("=" * 60)
transactions.info()
# Out:
# ...
# DIM FUND
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     str
#  2   scheme_name         40 non-null     str
#  3   category            40 non-null     str
#  4   sub_category        40 non-null     str
#  5   plan                40 non-null     str
#  6   launch_date         40 non-null     str
#  7   benchmark           40 non-null     str
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     str
#  13  risk_category       40 non-null     str
#  14  sebi_category_code  40 non-null     str
# dtypes: float64(2), int64(3), str(10)
# memory usage: 4.8 KB
#
# ...

# %% [markdown]
# print("Funds Shape:", funds.shape)
# print("NAV Shape:", nav.shape)
# print("Performance Shape:", performance.shape)
# print("Transactions Shape:", transactions.shape)
# print("Holdings Shape:", holdings.shape)

# %%
performance.describe().T
# Out:
#                     count          mean           std        min          25%  \
# amfi_code            40.0  120247.00000  14534.998667  100016.00  118632.7500
# return_1yr_pct       40.0      14.37600      4.883023       4.26      11.7350
# return_3yr_pct       40.0      14.08900      4.617253       5.14      12.0350
# return_5yr_pct       40.0      14.51675      4.454021       5.43      12.3400
# benchmark_3yr_pct    40.0      12.83550      4.740972       3.96      10.6900
# alpha                40.0       1.25350      0.447412       0.51       0.8875
# beta                 40.0       0.87325      0.224846       0.22       0.8900
# sharpe_ratio         40.0       1.36175      1.475805       0.80       0.8650
# sortino_ratio        40.0       2.08250      2.203144       1.03       1.2700
# std_dev_ann_pct      40.0      14.96250      6.669282       0.50      14.0000
# max_drawdown_pct     40.0     -19.20025      8.819164     -33.50     -25.0625
# ...

# %%
print("Funds")
print(funds.isnull().sum())

print("\nPerformance")
print(performance.isnull().sum())

print("\nTransactions")
print(transactions.isnull().sum())
# Out:
# Funds
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
#
# Performance
# amfi_code             0
# scheme_name           0
# fund_house            0
# category              0
# plan                  0
# return_1yr_pct        0
# return_3yr_pct        0
# return_5yr_pct        0
# benchmark_3yr_pct     0
# alpha                 0
# beta                  0
# sharpe_ratio          0
# sortino_ratio         0
# std_dev_ann_pct       0
# max_drawdown_pct      0
# aum_crore             0
# expense_ratio_pct     0
# morningstar_rating    0
# risk_grade            0
# dtype: int64
#
# Transactions
# investor_id           0
# ...

# %%
nav["date"] = pd.to_datetime(nav["date"])

monthly_nav = (
    nav.groupby(nav["date"].dt.to_period("M"))["nav"]
       .mean()
       .reset_index()
)

monthly_nav["date"] = monthly_nav["date"].astype(str)

monthly_nav.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 nav["date"] = pd.to_datetime(nav["date"])
#       2
#       3 monthly_nav = (
#       4     nav.groupby(nav["date"].dt.to_period("M"))["nav"]
#
# NameError: name 'nav' is not defined

# %%
type(nav)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 type(nav)
#
# NameError: name 'nav' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///bluestock_mf.db")

# %%
funds = pd.read_sql("SELECT * FROM dim_fund", engine)

nav = pd.read_sql("SELECT * FROM fact_nav", engine)

performance = pd.read_sql("SELECT * FROM fact_performance", engine)

transactions = pd.read_sql("SELECT * FROM fact_transactions", engine)

holdings = pd.read_sql("SELECT * FROM fact_holdings", engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Admin\OneDrive\Desktop\Mutual Fund Capstone Project\venv\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File c:\Users\Admin\OneDrive\Desktop\Mutual Fund Capstone Project\venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: no such table: dim_fund
#
# ...

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Admin\OneDrive\Desktop\Mutual Fund Capstone Project\notebooks

# %%
import os

print(os.path.exists("bluestock_mf.db"))
# Out:
# True

# %%
import sqlite3

conn = sqlite3.connect("bluestock_mf.db")

cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

print(cursor.fetchall())

conn.close()
# Out:
# []

# %%
engine = create_engine("sqlite:///bluestock_mf.db")

# %%
engine = create_engine("sqlite:///../bluestock_mf.db")

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Admin\OneDrive\Desktop\Mutual Fund Capstone Project\notebooks

# %%
import os
print(os.path.exists("bluestock_mf.db"))
# Out:
# True

# %%
notebooks/bluestock_mf.db
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 notebooks/bluestock_mf.db
#
# NameError: name 'notebooks' is not defined

# %%
import sqlite3

conn = sqlite3.connect("bluestock_mf.db")

cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

tables = cursor.fetchall()

print(tables)
# Out:
# []
